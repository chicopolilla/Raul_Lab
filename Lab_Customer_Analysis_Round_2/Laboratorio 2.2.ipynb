# %%
import pandas as pd

# %%
#Load data (file1.csv) in a new Jupyter notebook.
marketing_analysis = pd.read_csv("marketing_customer_analysis.csv")
marketing_analysis
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
#Show the dataframe shape.
marketing_analysis.shape
# Out:
# (10910, 26)

# %%
#Standardize header names.
marketing_analysis= marketing_analysis.drop('Unnamed: 0', axis=True)
marketing_analysis
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
marketing_analysis.dtypes
# Out:
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim          float64
# Months Since Policy Inception      int64
# Number of Open Complaints        float64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# ...

# %%
#Which columns are numerical?
marketing_analysis.select_dtypes(include=['int64','float64'] )
# Out:
#        Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
#Which columns are categorical?
marketing_analysis.select_dtypes(include='object' )
# Out:
#       Customer       State Response  Coverage Education Effective To Date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# ...

# %%
#Check and deal with NaN values.
conteo_nulos = marketing_analysis.isna().sum()
print(conteo_nulos.sort_values())
# Out:
# Customer                            0
# Total Claim Amount                  0
# Sales Channel                       0
# Renew Offer Type                    0
# Policy                              0
# Policy Type                         0
# Number of Policies                  0
# Months Since Policy Inception       0
# Marital Status                      0
# Location Code                       0
# Monthly Premium Auto                0
# Gender                              0
# EmploymentStatus                    0
# Effective To Date                   0
# Education                           0
# Coverage                            0
# Customer Lifetime Value             0
# Income                              0
# Vehicle Size                      622
# Vehicle Class                     622
# Response                          631
# State                             631
# Months Since Last Claim           633
# Number of Open Complaints         633
# Vehicle Type                     5482
# ...

# %%
# Primero Vehicle Size y Vehicle Class como los valores estan en blanco los cambiare a desconocido

marketing_analysis[['Vehicle Size','Vehicle Class']]= marketing_analysis[['Vehicle Size','Vehicle Class']].fillna('Desconocido')

# %%
# Response tiene valores NA los cambiare por "Sin respuesta"
marketing_analysis[['Response']] = marketing_analysis[['Response']].fillna('Sin respuesta')

# %%
# State tiene valores NA los cambiare por "Sin estado definido"
marketing_analysis[['State']] = marketing_analysis[['State']].fillna('Sin estado definido')

# %%
# Con la informacion que se tiene lo mejor sera cambiar los NA a 0 en los dos casos.
# Ya que se carece de informacion
marketing_analysis[['Months Since Last Claim','Number of Open Complaints']]= marketing_analysis[['Months Since Last Claim','Number of Open Complaints']].fillna(0)

# %%
# Solo hay vehiculos de Typo A hay tanto Na son 5482 casi la mitad de la data

marketing_analysis['Vehicle Type'].unique()
# Out:
# array([nan, 'A'], dtype=object)

# %%
# remplazaremos el valor de na en Vehicle Type por tipo "B"
marketing_analysis[['Vehicle Type']] = marketing_analysis[['Vehicle Type']].fillna('B')

# %%
conteo_nulos = marketing_analysis.isna().sum()
print(conteo_nulos.sort_values())
# Out:
# Customer                         0
# Vehicle Class                    0
# Total Claim Amount               0
# Sales Channel                    0
# Renew Offer Type                 0
# Policy                           0
# Policy Type                      0
# Number of Policies               0
# Number of Open Complaints        0
# Months Since Policy Inception    0
# Months Since Last Claim          0
# Vehicle Size                     0
# Monthly Premium Auto             0
# Location Code                    0
# Income                           0
# Gender                           0
# EmploymentStatus                 0
# Effective To Date                0
# Education                        0
# Coverage                         0
# Response                         0
# Customer Lifetime Value          0
# State                            0
# Marital Status                   0
# Vehicle Type                     0
# dtype: int64

# %% [markdown]
# Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.
#
#
# BONUS: Put all the previously mentioned data transformations into a function.

# %%
import pandas as pd
import numpy as np
import datetime

# %%
# funcion desde el principio
marketing_analysis[['Effective To Date']].to_datetime
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23052\2775724232.py in <module>
#       1 # funcion desde el principio
# ----> 2 marketing_analysis[['Effective To Date']].to_datetime
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_datetime'

# %%
marketing_analysis.dtypes
# Out:
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim          float64
# Months Since Policy Inception      int64
# Number of Open Complaints        float64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# ...

# %%
marketing_analysis['Effective To Date'] = pd.to_datetime(marketing_analysis['Effective To Date'])

# %%
marketing_analysis['Effective To Date']
# Out:
# 0       2011-02-18
# 1       2011-01-18
# 2       2011-02-10
# 3       2011-01-11
# 4       2011-01-17
#            ...
# 10905   2011-01-19
# 10906   2011-01-06
# 10907   2011-02-06
# 10908   2011-02-13
# 10909   2011-01-08
# Name: Effective To Date, Length: 10910, dtype: datetime64[ns]

# %%
marketing_analysis["Month"] = (
    marketing_analysis["Effective To Date"].dt.month_name()
)

# %%
# Solo hay datos de enero y febrero
marketing_analysis["Month"].unique()
# Out:
# array(['February', 'January'], dtype=object)

# %%
marketing_analysis[
  (  (marketing_analysis['Month'] =='February') | (marketing_analysis['Month'] =='January') )
]
# Out:
#       Customer                State  Customer Lifetime Value       Response  \
# 0      DK49336              Arizona              4809.216960             No
# 1      KX64629           California              2228.525238             No
# 2      LZ68649           Washington             14947.917300             No
# 3      XL78013               Oregon             22332.439460            Yes
# 4      QA50777               Oregon              9025.067525             No
# ...        ...                  ...                      ...            ...
# 10905  FE99816               Nevada             15563.369440             No
# 10906  KX53892               Oregon              5259.444853             No
# 10907  TL39050              Arizona             23893.304100             No
# 10908  WA60547           California             11971.977650             No
# 10909  IV32877  Sin estado definido              6857.519928  Sin respuesta
#
# ...

# %%
# Bonus
def tranformacion_date(x):
    y = pd.to_datetime(x)
    return y

# %%
#Load data (file1.csv) in a new Jupyter notebook.
marketing_analysis = pd.read_csv("marketing_customer_analysis.csv")
marketing_analysis =tranformacion_date( marketing_analysis['Effective To Date'])
# Out:
# dtype('<M8[ns]')

# %%
marketing_analysis.dtypes
# Out:
# dtype('<M8[ns]')

# %%
marketing_analysis
# Out:
# 0       2011-02-18
# 1       2011-01-18
# 2       2011-02-10
# 3       2011-01-11
# 4       2011-01-17
#            ...
# 10905   2011-01-19
# 10906   2011-01-06
# 10907   2011-02-06
# 10908   2011-02-13
# 10909   2011-01-08
# Name: Effective To Date, Length: 10910, dtype: datetime64[ns]
